# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #CNPJ 1

# %%
cnpj1 = pd.read_csv('/content/cnpjs_1.csv', sep=';')
# Out:
# <ipython-input-2-285ce60f4eb6>:1: DtypeWarning: Columns (10,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   cnpj1 = pd.read_csv('/content/cnpjs_1.csv', sep=';')

# %%
cnpj1.head()
# Out:
#          data            cnpj  cnpj_basico  cnpj_ordem  cnpj_dv  \
# 0  2023-02-15  97253082000207     97253082           2        7
# 1  2023-02-15   3151122000177      3151122           1       77
# 2  2022-09-11  27738772000181     27738772           1       81
# 3  2022-09-11  17096193000129     17096193           1       29
# 4  2022-09-11  23202167000130     23202167           1       30
#
#    identificador_matriz_filial          nome_fantasia  situacao_cadastral  \
# 0                            2                    NaN                   2
# 1                            1   AQUARIUS RESTAURANTE                   2
# 2                            1                    NaN                   2
# 3                            1                    NaN                   2
# 4                            1  PIZZARIA GRANDE SABOR                   2
#
#   data_situacao_cadastral  motivo_situacao_cadastral  ...         cep  ddd_1  \
# ...

# %%
cnpj1.describe()
# Out:
#                cnpj   cnpj_basico    cnpj_ordem       cnpj_dv  \
# count  4.292500e+04  4.292500e+04  42925.000000  42925.000000
# mean   3.237010e+13  3.237010e+07      2.298264     45.149074
# std    1.655612e+13  1.655612e+07     29.972925     30.513615
# min    1.128000e+09  1.128000e+03      1.000000      0.000000
# 25%    2.177579e+13  2.177579e+07      1.000000     17.000000
# 50%    3.587137e+13  3.587137e+07      1.000000     45.000000
# 75%    4.224415e+13  4.224415e+07      1.000000     72.000000
# max    9.867066e+13  9.867066e+07   2992.000000     99.000000
#
#        identificador_matriz_filial  situacao_cadastral  \
# count                 42925.000000             42925.0
# mean                      1.032312                 2.0
# std                       0.176830                 0.0
# min                       1.000000                 2.0
# 25%                       1.000000                 2.0
# 50%                       1.000000                 2.0
# ...

# %%
cnpj1['data_inicio_atividade'] = pd.to_datetime(cnpj1['data_inicio_atividade'])
cnpj1.set_index('data_inicio_atividade', inplace=True)
cnpj1.resample('Y').size().plot()
plt.show()

# %%
sns.countplot(x='sigla_uf', data=cnpj1)
plt.show()

# %%
sns.countplot(x='cnae_fiscal_principal', data=cnpj1)
plt.show()

# %% [markdown]
# #CNPJ 2

# %%
cnpj2 = pd.read_csv('/content/cnpjs_2.csv', sep=';')
# Out:
# <ipython-input-7-894e493f14bd>:1: DtypeWarning: Columns (10,25,29,31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   cnpj2 = pd.read_csv('/content/cnpjs_2.csv', sep=';')

# %%
cnpj2.head()
# Out:
#          data            cnpj  cnpj_basico  cnpj_ordem  cnpj_dv  \
# 0  2022-08-13  22114251000130   22114251.0         1.0     30.0
# 1  2022-08-13  13771040000189   13771040.0         1.0     89.0
# 2  2022-08-13  60359627000165   60359627.0         1.0     65.0
# 3  2022-08-13  36931709000158   36931709.0         1.0     58.0
# 4  2022-08-13  41721828000116   41721828.0         1.0     16.0
#
#    identificador_matriz_filial               nome_fantasia  \
# 0                          1.0    SALGATERIA NOVA BRASILIA
# 1                          1.0                         NaN
# 2                          1.0                         NaN
# 3                          1.0  LANCHONETE SIMPLES DELICIA
# 4                          1.0   MATHILDA BURGER E BROWNIE
#
#    situacao_cadastral data_situacao_cadastral  motivo_situacao_cadastral  ...  \
# 0                 2.0              2021-03-19                        0.0  ...
# ...

# %%
cnpj2.describe()
# Out:
#                cnpj   cnpj_basico     cnpj_ordem        cnpj_dv  \
# count  1.257120e+05  1.257110e+05  125711.000000  125711.000000
# mean   3.195367e+13  3.195392e+07       9.052637      45.015209
# std    1.475267e+13  1.475246e+07     112.124491      30.426372
# min    8.880002e+08  8.880000e+02       1.000000       0.000000
# 25%    2.222146e+13  2.222160e+07       1.000000      17.000000
# 50%    3.408058e+13  3.408058e+07       1.000000      44.000000
# 75%    4.175439e+13  4.175441e+07       1.000000      71.000000
# max    9.755429e+13  9.755429e+07    3767.000000      99.000000
#
#        identificador_matriz_filial  situacao_cadastral  \
# count                125711.000000            125711.0
# mean                      1.035661                 2.0
# std                       0.185445                 0.0
# min                       1.000000                 2.0
# 25%                       1.000000                 2.0
# ...

# %%
cnpj2['data_inicio_atividade'] = pd.to_datetime(cnpj2['data_inicio_atividade'])
cnpj2.set_index('data_inicio_atividade', inplace=True)
cnpj2.resample('Y').size().plot()
plt.show()

# %%
sns.countplot(x='sigla_uf', data=cnpj2)
plt.show()

# %%
sns.countplot(x='cnae_fiscal_principal', data=cnpj2)
plt.show()

# %% [markdown]
# #CNPJ 3

# %%
cnpj3 = pd.read_csv('/content/cnpjs_3.csv', sep=';')
# Out:
# <ipython-input-12-017a263b0500>:1: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   cnpj3 = pd.read_csv('/content/cnpjs_3.csv', sep=';')

# %%
cnpj3.head()
# Out:
#          data            cnpj  cnpj_basico  cnpj_ordem  cnpj_dv  \
# 0  2021-12-24  12556610000155   12556610.0         1.0     55.0
# 1  2021-12-24  26894870000145   26894870.0         1.0     45.0
# 2  2021-12-24  37981764000115   37981764.0         1.0     15.0
# 3  2021-12-24  22398569000190   22398569.0         1.0     90.0
# 4  2021-12-24  13082428000172   13082428.0         1.0     72.0
#
#    identificador_matriz_filial              nome_fantasia  situacao_cadastral  \
# 0                          1.0           BAR DO SEBASTIAO                 2.0
# 1                          1.0                CASA NOSTRA                 2.0
# 2                          1.0            LINNE BURG BEER                 2.0
# 3                          1.0  BAR E MERCEARIA VALDIVINO                 2.0
# 4                          1.0                        NaN                 2.0
#
#   data_situacao_cadastral  motivo_situacao_cadastral  ...         cep  ddd_1  \
# ...

# %%
cnpj3.describe()
# Out:
#                cnpj   cnpj_basico     cnpj_ordem        cnpj_dv  \
# count  1.739380e+05  1.739370e+05  173937.000000  173937.000000
# mean   2.826734e+13  2.826739e+07       1.012551      44.989686
# std    1.256396e+13  1.256398e+07       1.107996      30.434069
# min    2.259000e+09  2.259000e+03       1.000000       0.000000
# 25%    1.913045e+13  1.912994e+07       1.000000      17.000000
# 50%    2.855066e+13  2.855074e+07       1.000000      44.000000
# 75%    3.681542e+13  3.681542e+07       1.000000      71.000000
# max    9.859065e+13  9.859065e+07     453.000000      99.000000
#
#        identificador_matriz_filial  situacao_cadastral  \
# count                173937.000000            173937.0
# mean                      1.006221                 2.0
# std                       0.078626                 0.0
# min                       1.000000                 2.0
# 25%                       1.000000                 2.0
# ...

# %%
sns.countplot(x='cnae_fiscal_principal', data=cnpj3)
plt.show()

# %%
sns.countplot(x='sigla_uf', data=cnpj3)
plt.show()

# %% [markdown]
# #CNPJ 4

# %%
cnpj4 = pd.read_csv('/content/cnpjs_4.csv', sep=';')

# %%
cnpj4.head()
# Out:
#          data            cnpj  cnpj_basico  cnpj_ordem  cnpj_dv  \
# 0  2021-11-23   7984836000117      7984836           1       17
# 1  2021-11-23  34548163000125     34548163           1       25
# 2  2021-11-23  42044345000197     42044345           1       97
# 3  2021-11-23  43274883000130     43274883           1       30
# 4  2021-11-23  36401418000158     36401418           1       58
#
#    identificador_matriz_filial             nome_fantasia  situacao_cadastral  \
# 0                            1  MAXIMUS ESPACO E EVENTOS                   2
# 1                            1                Times Club                   2
# 2                            1       DISTRIBUIDORA MOURA                   2
# 3                            1                   DINARTE                   2
# 4                            1       ESQUENTA BRASIL PUB                   2
#
#   data_situacao_cadastral  motivo_situacao_cadastral  ...         cep  ddd_1  \
# ...

# %%
cnpj4.describe()
# Out:
#                cnpj   cnpj_basico     cnpj_ordem        cnpj_dv  \
# count  2.631090e+05  2.631090e+05  263109.000000  263109.000000
# mean   3.817150e+13  3.817150e+07       1.005218      44.896279
# std    7.246396e+12  7.246396e+06       0.125042      30.506731
# min    5.854100e+10  5.854100e+04       1.000000       0.000000
# 25%    3.556513e+13  3.556513e+07       1.000000      16.000000
# 50%    3.975729e+13  3.975729e+07       1.000000      44.000000
# 75%    4.305040e+13  4.305040e+07       1.000000      71.000000
# max    9.755177e+13  9.755176e+07      29.000000      99.000000
#
#        identificador_matriz_filial  situacao_cadastral  \
# count                263109.000000            263109.0
# mean                      1.003805                 2.0
# std                       0.061563                 0.0
# min                       1.000000                 2.0
# 25%                       1.000000                 2.0
# ...

# %%
cnpj4['data_inicio_atividade'] = pd.to_datetime(cnpj4['data_inicio_atividade'])
cnpj4.set_index('data_inicio_atividade', inplace=True)
cnpj4.resample('Y').size().plot()
plt.show()

# %%
sns.countplot(x='sigla_uf', data=cnpj4)
plt.show()

# %%
sns.countplot(x='id_pais', data=cnpj4)
plt.show()

# %%
sns.countplot(x='cnae_fiscal_principal', data=cnpj4)
plt.show()
